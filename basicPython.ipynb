# %% [markdown]
# # Python Fundamentals
#
# This Jupyter Notebook will take you through the basics of Python.
#
# If you have any questions, ask in the [Google Classroom]() or on the [website]().
# You can also contact the board members through email.
#
# Presidents:
# Vice President:

# %% [markdown]
# ### Printing

# %%
print("Hello World")  # outputs to console
# Out:
# Hello World

# %%
print("Hi, my name is\nbob")  # \n is the new line character
# Out:
# Hi, my name is
# bob

# %% [markdown]
# ### Operators

# %%
print(5 + 4)
# Out:
# 9

# %%
print(5 * 4)
# Out:
# 20

# %%
print(5 % 4)  # this is the modulo operator# - it returns remainder of 5 / 4
# Out:
# 1

# %% [markdown]
# ### Variables

# %%
x = 2
y = 3
print(x, y)
print(x + y)
# Out:
# 2 3
# 5

# %%
str1 = "First"
print(str1)
# Out:
# First

# %% [markdown]
# ### Types

# %% [markdown]
# **Numbers**
