# %% [markdown]
# # Python Fundamentals
#
# This Jupyter Notebook will take you through the basics of Python.
#
# If you have any questions, ask in the [Google Classroom]().<br>
# You can also contact the board members through email.
#
# Presidents: [Ethan Wang](800024257@fjuhsd.org) (800024257@fjuhsd.org), [Jason Li](800017994@fjuhsd.org) (800017994@fjuhsd.org)<br>
# Vice President: [Arta Modarres](800019220@fjuhsd.org) (800019220@fjuhsd.org), [Raymond Xu](800025091@fjuhsd.org) (800025091@fjuhsd.org)

# %% [markdown]
# ### Printing

# %%
print("Hello World")  # outputs to console
# Out:
# Hello World

# %%
print("Hi, my name is\nbob")  # \n is the new line character
# Out:
# Hi, my name is
# bob

# %%
# Try it yourself - Print "Hi, my name is *insert your name*"
# Insert Code Here



# Insert Code Here

# %% [markdown]
# ### Operators

# %%
print(5 + 4)

# %%
print(8 / 4)

# %%
print((5 * 4) + 2) # you can also use parentheses
# Out:
# 20

# %%
print(5 % 4)  # this is the modulo operator - it returns the remainder of 5 / 4
# Out:
# 1

# %% [markdown]
# ### Variables

# %% [markdown]
# Variables store data until it is changed or deleted.

# %%
x = 2
y = 3
print(x, y)
print(x + y)
# Out:
# 2 3
# 5

# %%
x = 3
print(x, y)
print(x + y)

# %%
str1 = "First"
print(str1)
# Out:
# First
# 4.5

# %% [markdown]
# ### Types

# %% [markdown]
# **Numbers**

# %% [markdown]
# Numbers can be integers (aka *int*) or decimals (aka *float*)

# %%
x = 1  # these are both numbers
y = 5
print(x, y)

# %%
x = 3
y = 6.2  # and so is this
print(x, y)
print(x + y)

# %%
x = 3
y = 6.0
print(x, y)
print(x + y)  # if one of the numbers is a decimal, the result will be a decimal
# Out:
# 3 6.0
# 9.0

# %% [markdown]
# **Strings**

# %% [markdown]
# Strings (aka *str*) are just words (combinations of characters)

# %%
str1 = "First"  # this is a string
str2 = "Second"
print(str1, str2)
# Out:
# First Second

# %%
print(str1 + str2)  # adding strings is called concatenation
# Out:
# FirstSecond

# %%
print(str1 + " " + str2)
# Out:
# First Second

# %% [markdown]
# Escape characters have special meanings and start with "\\"<br>
# The most common one is "\n", which starts a new line
# For a list of all Python escape characters, [click here](https://www.w3schools.com/python/gloss_python_escape_characters.asp).

# %% [markdown]
# **Arrays**

# %% [markdown]
# Arrays (aka *list*), can store a list of data of any type.

# %%
arr1 = [1, 2, 3]
arr2 = ["Hi", "my", "name", "is", "bob"]
print(arr1)
print(arr2)
# Out:
# [1, 2, 3]
# ['Hi', 'my', 'name', 'is', 'bob']

# %%
# Arrays start counting from 0, so the 0 element is the 1st element in the array
print(arr1[0])  # you can access an element in the array with arrName[number]
print(arr2[3])
# Out:
# 1
# is

# %%
print(arr2[-1])  # you can even start from the back of the array
# arrName[-1] gets the last element of the list
# Out:
# bob

# %%
# think about what this will print out before running it
print(arr2[-3])
# Out:
# name

# %%
# You can get the length of an array with len(arrName)
print(len(arr1))
print(len(arr2))
# Out:
# 3
# 5

# %%
# Try printing out "banana" from this list (There are 2 ways):
fruits = ["potato", 3, "h", "banana"]
# Insert Code Here



# Insert Code Here

# %% [markdown]
# **Getting input**

# %%
x = input() # input takes one line from the "command line"
print(x)
# Out:
# 1

# %%
x = input("What's your favorite color?")
print(x)
# Out:
# 2

# %% [markdown]
# ### if-else statements

# %% [markdown]
# if-else statements check if a condition is true and execute code based on that.

# %%
x = input()  # x will equal "3", since input() defaults to string
if x == 3:  # WARNING! This does not do what you expect it to - the types have to be the same too
    print("Correct")
else:
    print("Incorrect")
# Out:
# Incorrect

# %%
x = int(input())  # this is called casting - changing one data type to another
# str() changes it to a string
if x == 3:  # now this does what you expect it to
    print("Correct")
else:
    print("Incorrect")
# Out:
# Correct

# %%
x = input("What food do you like")  # you can put a string in input
if x == "Waffles" or x == "Pasta":  # case matters: "Waffles" and "waffles" are NOT the same
    print("Yum")
else:
    print("Yuck")
# Out:
# Yum

# %%
x = input("What's your favorite color")
y = int(input("What's your favorite number"))
if x == "Blue" and y == 3:
    print("Yay")
else:
    print("NOOOOOOOOOO")
# Out:
# NOOOOOOOOOO

# %%
# Try it yourself - write some code that asks a question and takes input. Use an if-else statement to print something in response.
# Insert code here



# Insert code here

# %% [markdown]
# **Booleans**

# %% [markdown]
# These are another data type.
# They can only be two values: True or False

# %%
if True:
    print("True")  # this wall always print
if False:
    print("False")  # this will never print
# Out:
# False

# %%
x = int(input("What's your favorite number")) == 42  # x will evaluate to True or False
if x:  # this is the same as 'if x == True'
    print("Yay")
else:
    print("Nooooo")  # This will execute if x is False
# Out:
# Yay

# %%
x = (2 == 2)  # evaluates to True
print(x)
x = 2 == 2  # parentheses not required, statements on the right of '=' are always evaluated first 
print(x)
# Out:
# True
# True

# %%
y = 2 == 3  # evaluates to False
print(x, y)

# %% [markdown]
# ### Loops

# %% [markdown]
# Loops allow you to execute statements multiple times:<br>
# The syntax is:<br>
# for *variable* in range(*begin*, *end*, *increment*):<br>
# &emsp;statements

# %%
for i in range(0, 3, 1):  # this goes from 0-2, incrementing by 1
    print(i)  # note that the end value - 3 - is excluded
# Out:
# 0
# 1
# 2

# %%
# only using 2 parameters defaults increment to 1
for i in range(2, 6):  # this goes from 2-5, incrementing by 1
    print(i)
# Out:
# 2
# 3

# %%
# only using 1 parameter defaults begin to 0, defaults increment to 1
for i in range(5):  # this goes from 0-4, incrementing by 1
    print(i)

# %%
arr1 = [1, 2, 3, 4, 5]
for i in range(len(arr1)):  # prints every single element in the list
    print(arr1[i])

# %%
for element in arr1:  # this is called a for-each loop - it goes through every single element of arr1
    print(element)

# %%
# arrays in arrays! (2D arrays)
arr1 = [[1, 2, 3], [4, 5, 6], ["bob", "says", "hi"], ["i", "like", "potatoes"]]
for outer in arr1:
    for inner in outer:
        print(inner, end=' ')  # prints inner + a space
    print()  # prints newline character
# Out:
# 1 2 3
# 4 5 6
# bob says hi
# i like potatoes

# %%
# Sometimes 2D arrays are represented this way:
# this only changes readability, not functionality
arr1 = [
        [1, 2, 3],
        [4, 5, 6],
        ["bob", "says", "hi"],
        ["i", "like", "potatoes"]
       ]
for outer in arr1:
    for inner in outer:
        print(inner, end=' ')  # prints inner + a space
    print()  # prints newline character

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# These are a more complex data type (or data structure). A dictionary is a list of key-value pairs.
#
# P.S. Dictionaries are called a map, hashmap, or hashtable in other languages.

# %%
dictionary = {
    "carName" : "Prius",
    "model" : 2,
    "id" : 3,
    "price" : 2000
}
